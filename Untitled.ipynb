# %%
import json
from pprint import pprint

with open('tweetCSV.csv') as data_file:    
    data = json.load(data_file)

pprint(data)
# Out:
# [{'authorName': 'Gendis',
#   'location': '',
#   'tweetCreatedAt': '2017-11-06 21:45:32',
#   'tweetText': 'good mornink warga indonesia',
#   'username': 'Gendis'},
#  {'authorName': 'Paket Online Store',
#   'location': 'Indonesia',
#   'tweetCreatedAt': '2017-11-06 21:45:30',
#   'tweetText': '“You are never too old to set another goal or to dream a new '
#                'dream.” C.S. Lewis',
#   'username': 'Paket Online Store'},
#  {'authorName': 'we12travel',
#   'location': 'Arnhem, The Netherlands',
#   'tweetCreatedAt': '2017-11-06 21:45:00',
#   'tweetText': 'RT All you need to know to travel #Borneo on a budget, a full '
#                'guide (14 articles) #travel #ttot via @cycloscopetweet '
#                'https://t.co/5kYkoYtPhm',
#   'username': 'we12travel'},
#  {'authorName': 'Strathclyde Amnesty',
#   'location': 'Glasgow',
#   'tweetCreatedAt': '2017-11-06 21:44:52',
#   'tweetText': 'RT @UNICEFKenya: #EarlyMomentsMatter that’s why '
# ...

# %%
data[0]
# Out:
# {'authorName': 'Gendis',
#  'location': '',
#  'tweetCreatedAt': '2017-11-06 21:45:32',
#  'tweetText': 'good mornink warga indonesia',
#  'username': 'Gendis'}

# %%
data[0]["tweetText"]
# Out:
# 'good mornink warga indonesia'

# %%
with open("id.stopwords.txt", "r") as ins:
    stopwords_id = []
    for line in ins:
        line = line.replace("\n", "")
        stopwords_id.append(line)
# Out:
# ['ada',
#  'adalah',
#  'adanya',
#  'adapun',
#  'agak',
#  'agaknya',
#  'agar',
#  'akan',
#  'akankah',
#  'akhir',
#  'akhiri',
#  'akhirnya',
#  'aku',
#  'akulah',
#  'amat',
#  'amatlah',
#  'anda',
#  'andalah',
#  'antar',
#  'antara',
#  'antaranya',
#  'apa',
#  'apaan',
#  'apabila',
#  'apakah',
#  'apalagi',
#  'apatah',
#  'artinya',
#  'asal',
#  'asalkan',
#  'atas',
#  'atau',
#  'ataukah',
#  'ataupun',
#  'awal',
#  'awalnya',
#  'bagai',
#  'bagaikan',
#  'bagaimana',
#  'bagaimanakah',
#  'bagaimanapun',
#  'bagi',
#  'bagian',
#  'bahkan',
#  'bahwa',
#  'bahwasanya',
#  'baik',
#  'bakal',
#  'bakalan',
#  'balik',
#  'banyak',
#  'bapak',
#  'baru',
#  'bawah',
#  'beberapa',
#  'begini',
#  'beginian',
#  'beginikah',
#  'beginilah',
#  'begitu',
#  'begitukah',
#  'begitulah',
#  'begitupun',
#  'bekerja',
#  'belakang',
#  'belakangan',
#  'belum',
#  'belumlah',
#  'benar',
#  'benarkah',
#  'benarlah',
#  'berada',
#  'berakhir',
#  'berakhirlah',
# ...

# %%
import nltk

from nltk import FreqDist
from nltk.tokenize import word_tokenize
from nltk.tokenize import wordpunct_tokenize
from nltk.corpus import stopwords

stop_words = set(stopwords.words('english'))
stop_words.update(['.', ',', '"', "'", '?', '!', ':', ';', '(', ')', '[', ']', '{', '}', '#','@'])
stop_words.update(stopwords_id)

list_of_words = []
for item in data:
    words = [i.lower() for i in wordpunct_tokenize(item["tweetText"]) if i.lower() not in stop_words]
    fdist = FreqDist(words)
    fdist.most_common()
    list_of_words.append(fdist)

list_of_words
# Out:
# [FreqDist({'good': 1, 'indonesia': 1, 'mornink': 1, 'warga': 1}),
#  FreqDist({'.”': 1,
#            'another': 1,
#            'c': 1,
#            'dream': 2,
#            'goal': 1,
#            'lewis': 1,
#            'never': 1,
#            'new': 1,
#            'old': 1,
#            'set': 1,
#            '“': 1}),
#  FreqDist({'/': 1,
#            '14': 1,
#            '5kykoytphm': 1,
#            '://': 1,
#            'articles': 1,
#            'borneo': 1,
#            'budget': 1,
#            'co': 1,
#            'cycloscopetweet': 1,
#            'full': 1,
#            'guide': 1,
#            'https': 1,
#            'know': 1,
#            'need': 1,
#            'rt': 1,
#            'travel': 2,
#            'ttot': 1,
#            'via': 1}),
#  FreqDist({'+': 1,
#            '4': 1,
#            'children': 1,
#            'china': 1,
#            'earlymomentsmatter': 1,
#            'education': 1,
#            'ikeafoundation': 1,
# ...
